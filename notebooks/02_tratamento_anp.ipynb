# %% [markdown]
# # Tratamento dos Dados da ANP
#
# ## Objetivo
#
# Preparar a base pública de preços de combustíveis automotivos da ANP para análise estatística e construção do dashboard no Power BI.
#
# ## Etapas de tratamento
#
# - Carregar o arquivo original sem modificá-lo.
# - Padronizar os nomes das colunas.
# - Converter a data da coleta.
# - Converter o valor de venda para número decimal.
# - Remover a coluna de valor de compra.
# - Avaliar e tratar registros duplicados.
# - Validar as unidades de medida.
# - Validar a qualidade da base tratada.
# - Exportar o resultado para `data/processed`.

# %%
from pathlib import Path

import pandas as pd
